# %% [markdown]
# # Dino Custom Model - Ollama

# %%
# !apt-get update && apt-get install -y zstd curl

# %%
# !curl -fsSL https://ollama.com/install.sh | sh

# %%
import subprocess, time
subprocess.Popen(['ollama', 'serve'])
time.sleep(3)
print('Ollama server started')

# %%
# !ollama pull phi3

# %%
modelfile = '''FROM phi3
PARAMETER temperature 0.7
SYSTEM You are Rexs Dino assistant. You know about DinoScan security scanner, Dino Dynasty OS, trading bots, and OpenClaw skills.'''
with open('Modelfile', 'w') as f: f.write(modelfile)

# %%
# !ollama create rex-dino -f Modelfile

# %%
# !ollama run rex-dino 'What is DinoScan? 1 sentence.'
