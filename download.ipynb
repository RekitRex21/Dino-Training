# %% [markdown]
# # Download Model

# %%
import subprocess
subprocess.run(['tar', '-czvf', 'rex-dino.tar.gz', '-C', '/root/.ollama/models', '.'], capture_output=True)
print('Model archived! Right-click rex-dino.tar.gz in Files panel to download')
